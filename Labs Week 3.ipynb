# %% [markdown]
# # Limits of Diversifaction

# %%
# %load_ext autoreload
# %autoreload 2

import risk_kit as rk
import pandas as pd
import numpy as np

ind_return = rk.get_ind_returns()
ind_size = rk.get_ind_size()
ind_nfirms = rk.get_ind_nfirms()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind_mktcap = ind_nfirms * ind_size
ind_mktcap.shape
ind_mktcap.head()
# Out:
#             Food   Beer    Smoke   Games  Books   Hshld   Clths    Hlth  \
# 1926-07  1547.14  21.36   955.52  184.87  24.04  178.16  220.32  178.64
# 1926-08  1552.30  20.25   967.52  190.19  26.66  177.04  237.96  180.60
# 1926-09  1591.00  25.74  1024.48  191.10  29.34  169.44  231.48  187.11
# 1926-10  1597.02  26.76  1030.72  201.32  28.84  169.84  228.36  188.09
# 1926-11  1542.84  25.86  1041.28  191.66  31.58  161.12  228.36  185.78
#
#            Chems  Txtls  ...    Telcm  Servs   BusEq   Paper    Trans  Whlsl  \
# 1926-07   979.03  80.34  ...  1751.80  40.80  396.90  212.10  4951.34   2.38
# 1926-08  1056.21  80.60  ...  1766.35  44.25  404.18  227.16  5031.26   1.80
# 1926-09  1114.01  87.23  ...  1804.80  45.15  417.27  220.92  5255.48   1.90
# 1926-10  1163.99  88.66  ...  1820.80  45.90  416.64  208.62  5241.42   1.76
# 1926-11  1106.02  88.92  ...  1818.70  44.67  411.18  196.80  5087.50   1.48
#
#            Rtail  Meals     Fin   Other
# ...

# %%
total_mktcap = ind_mktcap.sum(axis="columns")

# %%
total_mktcap.plot()
# Out:
# <Axes: >

# %%
ind_capweight = ind_mktcap.divide(total_mktcap, axis="rows")
ind_capweight.head()
# This gives us the weights of all the industries in the period of time in the total market cap.
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1926-07  0.058037  0.000801  0.035844  0.006935  0.000902  0.006683  0.008265
# 1926-08  0.056578  0.000738  0.035264  0.006932  0.000972  0.006453  0.008673
# 1926-09  0.056699  0.000917  0.036510  0.006810  0.001046  0.006038  0.008249
# 1926-10  0.056920  0.000954  0.036736  0.007175  0.001028  0.006053  0.008139
# 1926-11  0.056725  0.000951  0.038285  0.007047  0.001161  0.005924  0.008396
#
#              Hlth     Chems     Txtls  ...     Telcm     Servs     BusEq  \
# 1926-07  0.006701  0.036726  0.003014  ...  0.065714  0.001531  0.014889
# 1926-08  0.006583  0.038497  0.002938  ...  0.064380  0.001613  0.014732
# 1926-09  0.006668  0.039700  0.003109  ...  0.064318  0.001609  0.014870
# 1926-10  0.006704  0.041486  0.003160  ...  0.064896  0.001636  0.014850
# 1926-11  0.006831  0.040665  0.003269  ...  0.066868  0.001642  0.015118
#
# ...

# %%
ind_capweight["1926"].sum(axis="columns")
# We check to see if every column adds up to 100 percent as required.
# Out:
# /var/folders/hh/1qw11svj2913226t4vlc07b00000gn/T/ipykernel_76581/1768069357.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ind_capweight["1926"].sum(axis="columns")
# 1926-07    1.0
# 1926-08    1.0
# 1926-09    1.0
# 1926-10    1.0
# 1926-11    1.0
# 1926-12    1.0
# Freq: M, dtype: float64

# %%
ind_capweight[["Fin", "Steel"]].plot()
# Out:
# <Axes: >

# %%
total_market_return = (ind_capweight*ind_return).sum(axis="columns")

# %%
total_market_return.plot()
# Out:
# <Axes: >

# %%
total_market_index = rk.drawdown(total_market_return).Wealth
total_market_index.plot()
# Out:
# <Axes: >

# %%
total_market_index["1980":].plot()
# Out:
# <Axes: >

# %%
total_market_index["1980":].plot()
total_market_index["1980":].rolling(window=36).mean().plot()
# Out:
# <Axes: >

# %%
tmi_tr36rets = total_market_return.rolling(window=36).aggregate(rk.annualize_rets, periods_per_year=12)
tmi_tr36rets.plot(figsize=(12,6),label="Tr36 mo return")
total_market_return.plot(label="Returns", legend= True)
# Out:
# <Axes: >

# %% [markdown]
# # Rolling Correlation - along with MultiIndexes and .groupby

# %%
ts_corr = ind_return.rolling(window=36).corr()
ts_corr.tail()
# As we can see this is a multiIndex table with a square matrix because of the correlation
# Out:
#                    Food      Beer     Smoke     Games     Books     Hshld  \
# 2018-12 Whlsl  0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail  0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals  0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin    0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other  0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                   Clths      Hlth     Chems     Txtls  ...     Telcm  \
# 2018-12 Whlsl  0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail  0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals  0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin    0.425899  0.658468  0.760151  0.577090  ...  0.420863
#         Other  0.467099  0.645035  0.712511  0.520953  ...  0.607868
#
#                   Servs     BusEq     Paper     Trans     Whlsl     Rtail  \
# ...

# %%
ind_return.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
# To make the ts_corr clear we give index names to the dataframe
ts_corr.index.names = ['date', 'industry']
ts_corr.tail()
# Out:
#                       Food      Beer     Smoke     Games     Books     Hshld  \
# date    industry
# 2018-12 Whlsl     0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail     0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals     0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin       0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other     0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                      Clths      Hlth     Chems     Txtls  ...     Telcm  \
# date    industry                                          ...
# 2018-12 Whlsl     0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail     0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals     0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin       0.425899  0.658468  0.760151  0.577090  ...  0.420863
# ...

# %%
ind_tr36corr = ts_corr.groupby(level='date').apply(lambda cormat: cormat.values.mean())

# %%
ind_tr36corr.plot()
# Out:
# <Axes: xlabel='date'>

# %%
tmi_tr36rets.plot(label="Tr36 Mo Rets", figsize=(12,6), legend=True)
ind_tr36corr.plot(label="Tr36 Mo Corr", legend=True, secondary_y=True)
#Diversification does not help you when the markets are crashing.
# Out:
# <Axes: >

# %%
tmi_tr36rets["2007":].plot(label="Tr36 Mo Rets", figsize=(12,6), legend=True)
ind_tr36corr["2007":].plot(label="Tr36 Mo Corr", legend=True, secondary_y=True)
#Diversification does not help you when the markets are crashing.
# Out:
# <Axes: >

# %%
# The correlation between the returns and the average correlation
tmi_tr36rets.corr(ind_tr36corr)
# Out:
# -0.28010065062883993

# %% [markdown]
# # Constant Proportion Portfolio Insurance (CPPI)
# This procedure dynamically allocates total assets to a **risky asset** and a **safe asset**.
#
# We have a minimum threshold that our asset shouldn't go below. This threshold is called the **floor** Above this threshold we can put our assets to risky assets. This margin above the threshold is called the **cushion**. Cushion can be calculated by the difference in between the floor and the portfolio value.
#
# Running Max Process, that keeps track of maximum value of day zero and day t that has been reached by the underlying asset value process.
#
# Smooth-Pasting is the way to choose the threshold values.
#
# **The primary objective of CCPI is to create a balance between capital preservation and the growth potential. This is done by dynamically adjusting the cushion. CCPI strategies aims to protect you from severe losses that can happen because of the markets nature.**

# %% [markdown]
# # Implementing Portfolio Insurance (CPPI) and Drawdown Constraints

# %%
ind_return = rk.get_ind_returns()
tmi_return = rk.get_total_market_index_returns()

# %%
risky_r =  ind_return["2000":][["Steel", "Fin", "Beer"]]

# %%
risky_r.shape
# Out:
# (228, 3)

# %%
#Safe Asset
safe_r = pd.DataFrame().reindex_like(risky_r) #reindex_like gives you the same shape as another dataframe

# %%
safe_r.shape
# Out:
# (228, 3)

# %%
safe_r[:] = 0.03/12
start = 1000
floor = 0.8

# %% [markdown]
# 1. Cushion - Asset Value minus Floor Value
# 2. Compute an allocation to Safe and Risky Assets -> m*risk budget
# 3. Recompute the Asset Value based on the returns

# %%
dates = risky_r.index
n_steps = len(dates)
account_value = start
floor_value = start*floor
m = 3
account_history = pd.DataFrame().reindex_like(risky_r)
cushion_history = pd.DataFrame().reindex_like(risky_r)
risky_w_history = pd.DataFrame().reindex_like(risky_r)

for step in range(n_steps):
    cushion = (account_value - floor_value)/account_value
    risky_w = m*cushion
    risky_w = np.minimum(risky_w, 1)
    risky_w = np.maximum(risky_w, 0)
    safe_w = 1-risky_w
    risky_alloc = account_value*risky_w
    safe_alloc = account_value*safe_w
    ## update the account value for this time step
    account_value = risky_alloc*(1+risky_r.iloc[step]) + safe_alloc*(1+safe_r.iloc[step])
    # save the values so I can look at the history and plot it etc
    cushion_history.iloc[step] = cushion
    risky_w_history.iloc[step] = risky_w
    account_history.iloc[step] = account_value

# %%
account_history.head()
# Out:
#                Steel          Fin        Beer
# 2000-01   984.380000   974.480000  987.320000
# 2000-02  1023.292876   931.167544  922.971256
# 2000-03  1047.555176   998.187296  924.835988
# 2000-04  1042.079009   973.927479  939.993701
# 2000-05  1007.137753  1001.460033  991.145489

# %%
risky_wealth = start*(1+risky_r).cumprod()

# %%
risky_wealth.plot()
# Out:
# <Axes: >

# %%
ax = account_history["Beer"].plot()
risky_wealth["Beer"].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
risky_w_history.plot()
# Out:
# <Axes: >

# %%
ind = "Fin"
ax = account_history[ind].plot()
risky_wealth[ind].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
ind = "Steel"
ax = account_history[ind].plot()
risky_wealth[ind].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
rk.summary_stats(risky_r)
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.002790        0.102102 -0.326334  4.144381
# Fin             0.055166        0.063055 -0.533218  4.995534
# Beer            0.080598        0.045410 -0.493545  4.173881
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.150139            0.208117     -0.313789     -0.758017
# Fin                   0.091224            0.132175      0.387676     -0.718465
# Beer                  0.063015            0.091442      1.083977     -0.271368

# %%
btr = rk.run_cppi(risky_r)

# %%
rk.summary_stats(btr['Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# Steel          -0.005167        0.056933 -1.995143  17.110190
# Fin             0.040894        0.043041 -0.946504   6.051414
# Beer            0.075544        0.037740 -0.669250   4.760879
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.091995            0.130153     -0.601931     -0.655198
# Fin                   0.065535            0.091621      0.245827     -0.549673
# Beer                  0.052923            0.074908      1.174099     -0.259582

# %%
rk.summary_stats(btr['Risky Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.001320        0.102300 -0.330333  4.132666
# Fin             0.057941        0.063080 -0.543630  5.015294
# Beer            0.082286        0.045453 -0.502368  4.181533
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.150415            0.208117     -0.299208     -0.758017
# Fin                   0.091172            0.132175      0.430333     -0.718465
# Beer                  0.063037            0.091442      1.119079     -0.271368

# %%
#Drawdown Constraint

btr = rk.run_cppi(ind_return["2007":][["Steel", "Fin", "Beer"]], drawdown = 0.25)

# %%
ax = btr["Wealth"].plot(figsize=(12, 6))
btr["Risky Wealth"].plot(ax = ax, style = "--")
# Out:
# <Axes: >

# %%
rk.summary_stats(btr['Wealth'].pct_change().dropna())
# We can see because of the drawdown constraint our maximum drawdown has dropped to %24.
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel           0.003784        0.031730 -0.441089  5.220481
# Fin             0.041975        0.027793 -0.355163  4.153860
# Beer            0.084375        0.028196 -0.744111  4.571533
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.047371            0.066991     -0.804484     -0.248059
# Fin                   0.038342            0.054111      0.419022     -0.243626
# Beer                  0.037937            0.051189      1.876655     -0.161186

# %%
rk.summary_stats(btr['Risky Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.039660        0.100154 -0.459951  4.782828
# Fin             0.027364        0.069362 -0.695200  4.621401
# Beer            0.111554        0.041829 -0.670797  4.650878
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.152288            0.203837     -0.678086     -0.758017
# Fin                   0.105744            0.149862     -0.037843     -0.718465
# Beer                  0.056497            0.077388      1.897212     -0.271368

# %% [markdown]
# # Random Walk Generation
#
# So by using Brownian Motion Model, we try evaluate a stock price.
#
# The GBM provides analysts and traders to understand and estimate the price range for an asset, so that they can make informed investment decisions.
#
# The GBM creates a mathematical framework to aid risk management and portfolio optimization.
